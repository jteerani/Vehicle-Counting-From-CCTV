# %%
#Get runtime details
# %cat /etc/lsb-release
# Out:
# DISTRIB_ID=Ubuntu
# DISTRIB_RELEASE=18.04
# DISTRIB_CODENAME=bionic
# DISTRIB_DESCRIPTION="Ubuntu 18.04.5 LTS"

# %%
#Update the Repo list
# !apt-get update
# Out:
# Hit:1 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:4 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:5 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:7 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:8 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Hit:9 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Ign:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:11 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:12 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# ...

# %%
#Show the current working directory
# %pwd
# Out:
# '/content'

# %%
#Unzip the darknet zip file to the /content folder
# !unzip "/content/drive/MyDrive/Colab Notebooks/DL_Gift/custom_yolo_model/darknet.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: darknet/build/darknet/x64/data/labels/106_4.png
#   inflating: darknet/build/darknet/x64/data/labels/106_5.png
#   inflating: darknet/build/darknet/x64/data/labels/106_6.png
#   inflating: darknet/build/darknet/x64/data/labels/106_7.png
#   inflating: darknet/build/darknet/x64/data/labels/107_0.png
#   inflating: darknet/build/darknet/x64/data/labels/107_1.png
#   inflating: darknet/build/darknet/x64/data/labels/107_2.png
#   inflating: darknet/build/darknet/x64/data/labels/107_3.png
#   inflating: darknet/build/darknet/x64/data/labels/107_4.png
#   inflating: darknet/build/darknet/x64/data/labels/107_5.png
#   inflating: darknet/build/darknet/x64/data/labels/107_6.png
#  extracting: darknet/build/darknet/x64/data/labels/107_7.png
#   inflating: darknet/build/darknet/x64/data/labels/108_0.png
#   inflating: darknet/build/darknet/x64/data/labels/108_1.png
#   inflating: darknet/build/darknet/x64/data/labels/108_2.png
# ...

# %%
#Go inside the darknet folder of our runtime
# %cd /content/darknet
# Out:
# /content/darknet

# %%
#Install dos2unix to convert dos files to unix encoding
# !sudo apt install dos2unix
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# dos2unix is already the newest version (7.3.4-3).
# 0 upgraded, 0 newly installed, 0 to remove and 48 not upgraded.

# %%
#Convert all files in darknet folder to unix encoding
# !find . -type f -print0 | xargs -0 dos2unix
# Out:
# Streaming output truncated to the last 5000 lines.
# dos2unix: Skipping binary file ./custom_data/custom_img/410.jpg
# dos2unix: converting file ./custom_data/custom_img/408.txt to Unix format...
# dos2unix: Binary symbol 0x00 found at line 1
# dos2unix: Skipping binary file ./custom_data/custom_img/1489.jpg
# dos2unix: Binary symbol 0x00 found at line 1
# dos2unix: Skipping binary file ./custom_data/custom_img/847.jpg
# dos2unix: converting file ./custom_data/custom_img/340.txt to Unix format...
# dos2unix: Binary symbol 0x00 found at line 1
# dos2unix: Skipping binary file ./custom_data/custom_img/79.jpg
# dos2unix: converting file ./custom_data/custom_img/806.txt to Unix format...
# dos2unix: Binary symbol 0x00 found at line 1
# dos2unix: Skipping binary file ./custom_data/custom_img/output_315.jpg
# dos2unix: Binary symbol 0x00 found at line 1
# dos2unix: Skipping binary file ./custom_data/custom_img/238.jpg
# ...

# %%
#Give executable permission for files in /content/darknet
# !chmod +x /content/darknet

# %%
# %pwd
# Out:
# '/content/darknet'

# %%
#Compile the darknet framework
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
# ...

# %%
#Test the darkent framework with sample object detection
# !./darknet detector test cfg/coco.data cfg/yolov4.cfg yolov4.weights data/person.jpg
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 700, cudnn_half = 0, GPU: Tesla V100-SXM2-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 8, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    608 x 608 x   3 ->  608 x 608 x  32 0.639 BF
#    1 conv     64       3 x 3/ 2    608 x 608 x  32 ->  304 x 304 x  64 3.407 BF
#    2 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    3 route  1 		                           ->  304 x 304 x  64
#    4 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    5 conv     32       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  32 0.379 BF
#    6 conv     64       3 x 3/ 1    304 x 304 x  32 ->  304 x 304 x  64 3.407 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 304 x 304 x  64 0.006 BF
# ...

# %%
# %pwd
# Out:
# '/content/darknet'

# %%
#Remove the default backup folder of darknet in runtime
# !rm /content/darknet/backup -r

# %%
#Create a symbolic link from runtime darknet folder to google drive backup folder with the name 'backup'
# !ln -s /content/drive/MyDrive/'Colab Notebooks'/DL_Gift/custom_yolo_model/custom_weights/backup /content/darknet

# %%
#check the directory
# %pwd
# Out:
# '/content/darknet'

# %%
#Proceed with fresh Training Using the custom dataset
# !./darknet detector train custom_data/labelled_data.data custom_yolov4.cfg yolov4-tiny.weights -map -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 4857686, rewritten_bbox = 0.035449 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.777147), count: 21, class_loss = 1.933183, iou_loss = 46.431595, total_loss = 48.364780
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.861691), count: 27, class_loss = 0.862158, iou_loss = 24.400434, total_loss = 25.262592
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.921248), count: 10, class_loss = 0.005390, iou_loss = 0.952727, total_loss = 0.958117
#  total_bbox = 4857744, rewritten_bbox = 0.035449 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.823434), count: 19, class_loss = 0.409472, iou_loss = 52.910278, total_loss = 53.319752
# ...

# %%
#Resuming training from the last best weight file
# !./darknet detector train custom_data/labelled_data.data custom_yolov4.cfg /content/drive/MyDrive/'Colab Notebooks'/DL_Gift/custom_yolo_model/custom_weights/backup/custom_yolov4_best.weights
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
# custom_yolov4
#  0 : compute_capability = 700, cudnn_half = 0, GPU: Tesla V100-SXM2-16GB
# net.optimized_memory = 0
# mini_batch = 5, batch = 60, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    3 route  1 		                           ->  208 x 208 x  64
#    4 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    5 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    6 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
# ...

# %%
# !cp /content/darknet/chart.png /content/drive/MyDrive/'Colab Notebooks'/DL_Gift/custom_yolo_model/custom_weights/backup/
